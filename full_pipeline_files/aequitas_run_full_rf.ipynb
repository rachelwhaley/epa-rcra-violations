# %%
import new_pipe
import has_violation
import pandas as pd

import seaborn as sns
from aequitas.group import Group
from aequitas.bias import Bias
from aequitas.fairness import Fairness
from aequitas.plotting import Plot

# %%
# this is the features dataframe
features_df = pd.read_csv("feature_df.csv")

# %%
features_df.shape
# Out:
# (98008, 39)

# %%
# features_df = new_pipe.add_acs_features(df)

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98008 entries, 0 to 98007
# Data columns (total 39 columns):
# Unnamed: 0                            98008 non-null int64
# sum_evalSTATE_CODE                    98008 non-null float64
# other alone                           98008 non-null float64
# population                            98008 non-null float64
# p5top99                               98008 non-null float64
# 1p25to1p49_y                          98008 non-null float64
# last early  ID_NUMBER                 98008 non-null float64
# 1to1p24_y                             98008 non-null float64
# last late  ID_NUMBER                  98008 non-null float64
# sum_evalID_NUMBER                     98008 non-null float64
# NumInMyState                          98008 non-null float64
# NumInMyZIP                            98008 non-null float64
# two or more                           98008 non-null float64
# early  ID_NUMBER count                98008 non-null float64
# two or more some other                98008 non-null float64
# 1p50to1p84                            98008 non-null float64
# asian alone                           98008 non-null float64
# late  ID_NUMBER sum                   98008 non-null float64
# sum_evalZIP_CODE                      98008 non-null float64
# IsLQG                                 98008 non-null int64
# 2andver                               98008 non-null float64
# DAYS_SINCE_VIOLATIONS_IN_ID_NUMBER    98008 non-null float64
# late  ID_NUMBER count                 98008 non-null float64
# lastSTATE_CODE                        98008 non-null float64
# Unnamed: 0_y                          98008 non-null float64
# Unnamed: 0.1                          98008 non-null int64
# Unnamed: 0_x                          98008 non-null int64
# under_p5_y                            98008 non-null float64
# early  ID_NUMBER sum                  98008 non-null float64
# median income                         98008 non-null float64
# IsTSDF                                98008 non-null int64
# pacific alone                         98008 non-null float64
# 1p85to1p99_y                          98008 non-null float64
# lastID_NUMBER                         98008 non-null float64
# black alone                           98008 non-null float64
# NUMBER_VIOLATIONS_IN_ID_NUMBER        98008 non-null float64
# native alone                          98008 non-null float64
# white alone                           98008 non-null float64
# lastZIP_CODE                          98008 non-null float64
# dtypes: float64(34), int64(5)
# memory usage: 29.2 MB

# %%
import epa_pipeline as ep

# %%
preds = pd.read_csv("dave_predictions.csv")

# %%
preds.shape
# Out:
# (98008, 18)

# %%
preds_trim = preds.iloc[:,0:5]

# %%
preds_trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98008 entries, 0 to 98007
# Data columns (total 5 columns):
# Unnamed: 0                                                                                                              98008 non-null int64
# RF{'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct     98008 non-null int64
# RF{'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct    98008 non-null int64
# RF{'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct     98008 non-null int64
# RF{'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct    98008 non-null int64
# dtypes: int64(5)
# memory usage: 3.7 MB

# %%
preds_all = preds_trim.merge(features_df, left_index=True, right_index=True)

# %%
preds_truth = preds["truth"]

# %%
preds_all.shape
# Out:
# (98008, 44)

# %%
preds_all.shape
# Out:
# (98008, 44)

# %%
preds_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98008 entries, 0 to 98007
# Data columns (total 44 columns):
# Unnamed: 0_x                                                                                                            98008 non-null int64
# RF{'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct     98008 non-null int64
# RF{'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct    98008 non-null int64
# RF{'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct     98008 non-null int64
# RF{'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct    98008 non-null int64
# Unnamed: 0_y                                                                                                            98008 non-null int64
# sum_evalSTATE_CODE                                                                                                      98008 non-null float64
# other alone                                                                                                             98008 non-null float64
# population                                                                                                              98008 non-null float64
# p5top99                                                                                                                 98008 non-null float64
# 1p25to1p49_y                                                                                                            98008 non-null float64
# last early  ID_NUMBER                                                                                                   98008 non-null float64
# 1to1p24_y                                                                                                               98008 non-null float64
# last late  ID_NUMBER                                                                                                    98008 non-null float64
# sum_evalID_NUMBER                                                                                                       98008 non-null float64
# NumInMyState                                                                                                            98008 non-null float64
# NumInMyZIP                                                                                                              98008 non-null float64
# two or more                                                                                                             98008 non-null float64
# early  ID_NUMBER count                                                                                                  98008 non-null float64
# two or more some other                                                                                                  98008 non-null float64
# 1p50to1p84                                                                                                              98008 non-null float64
# asian alone                                                                                                             98008 non-null float64
# late  ID_NUMBER sum                                                                                                     98008 non-null float64
# sum_evalZIP_CODE                                                                                                        98008 non-null float64
# IsLQG                                                                                                                   98008 non-null int64
# 2andver                                                                                                                 98008 non-null float64
# DAYS_SINCE_VIOLATIONS_IN_ID_NUMBER                                                                                      98008 non-null float64
# late  ID_NUMBER count                                                                                                   98008 non-null float64
# lastSTATE_CODE                                                                                                          98008 non-null float64
# Unnamed: 0_y                                                                                                            98008 non-null float64
# Unnamed: 0.1                                                                                                            98008 non-null int64
# Unnamed: 0_x                                                                                                            98008 non-null int64
# under_p5_y                                                                                                              98008 non-null float64
# early  ID_NUMBER sum                                                                                                    98008 non-null float64
# median income                                                                                                           98008 non-null float64
# IsTSDF                                                                                                                  98008 non-null int64
# pacific alone                                                                                                           98008 non-null float64
# 1p85to1p99_y                                                                                                            98008 non-null float64
# lastID_NUMBER                                                                                                           98008 non-null float64
# black alone                                                                                                             98008 non-null float64
# NUMBER_VIOLATIONS_IN_ID_NUMBER                                                                                          98008 non-null float64
# native alone                                                                                                            98008 non-null float64
# white alone                                                                                                             98008 non-null float64
# lastZIP_CODE                                                                                                            98008 non-null float64
# dtypes: float64(34), int64(10)
# memory usage: 32.9 MB

# %%
import numpy as np

# %%
def aequitas_prep(df, q):
    # Column names = families_under_poverty_line, median income
    # df["families_under_pl_quartile"] = df["families_under_poverty_line"].quantile([0, .25, .5, .75, 1])
    # df["median_income_quartile"] = df["median income"].quantile([0, .25, .5, .75, 1])  # ([0, 25000, 50000, 100000, 150000])
    # for _, col in enumerate(["median income"]): #, "families_under_poverty_line"]):
        # col_q = col + '_q{}'.format(q)
        # df[col_q] = pd.cut(x=df["median income"],bins=q, labels=False) # pd.qcut(df[col], q, labels=False)
        # TODO: make these into equal buckets
    buckets = np.linspace(df["median income"].min(), df["median income"].max(), num=q)
    df["median_income_quantile"] = pd.cut(df["median income"], buckets)
    df["median_income_quantile"] = df["median_income_quantile"].astype(str)
    
    # white alone, black alone, native alone, asian alone, pacific alone, other alone, two or more
    df["race_majority"] = df[['white alone', 'black alone', 'native alone', 'asian alone', 'pacific alone',
                              'other alone', 'two or more']].idxmax(axis=1)
    return df

# %%
preds_all_prepped = aequitas_prep(preds_all,5)

# %%
preds_all_prepped = preds_all_prepped.drop('Unnamed: 0_x', 1)# .columns

# %%
preds_all_prepped = preds_all_prepped.drop('Unnamed: 0_y', 1)

# %%
preds_all_prepped.columns
# Out:
# Index(['RF{'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct',
#        'RF{'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct',
#        'RF{'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct',
#        'RF{'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct',
#        'sum_evalSTATE_CODE', 'other alone', 'population', 'p5top99',
#        '1p25to1p49_y', 'last early  ID_NUMBER', '1to1p24_y',
#        'last late  ID_NUMBER', 'sum_evalID_NUMBER', 'NumInMyState',
#        'NumInMyZIP', 'two or more', 'early  ID_NUMBER count',
#        'two or more some other', '1p50to1p84', 'asian alone',
#        'late  ID_NUMBER sum', 'sum_evalZIP_CODE', 'IsLQG', '2andver',
#        'DAYS_SINCE_VIOLATIONS_IN_ID_NUMBER', 'late  ID_NUMBER count',
#        'lastSTATE_CODE', 'Unnamed: 0.1', 'under_p5_y', 'early  ID_NUMBER sum',
#        'median income', 'IsTSDF', 'pacific alone', '1p85to1p99_y',
#        'lastID_NUMBER', 'black alone', 'NUMBER_VIOLATIONS_IN_ID_NUMBER',
#        'native alone', 'white alone', 'lastZIP_CODE', 'median_income_quantile',
#        'race_majority'],
#       dtype='object')

# %%
preds_all_prepped = preds_all_prepped.merge(preds_truth, right_index=True, left_index=True)

# %%
df_for_equity = preds_all_prepped.filter(["RF{'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct", "truth", "median_income_quantile", "race_majority"])

# %%
df_for_equity.rename(columns={"RF{'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 10000, 'n_jobs': -1}_at_0.2pct":'score', "truth":'label_value'},inplace=True)

# %%
df_for_equity.shape
# Out:
# (98008, 4)

# %%
df_for_equity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98008 entries, 0 to 98007
# Data columns (total 4 columns):
# score                     98008 non-null int64
# label_value               98008 non-null float64
# median_income_quantile    98008 non-null object
# race_majority             98008 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.0+ MB

# %%
rf_for_aequitas = df_for_equity.copy(deep=True)

# %%
rf_for_aequitas["label_value"] = rf_for_aequitas["label_value"].astype(int)

# %%
g = Group()
import aequitas.preprocessing as ap

# %%
# rf_for_aequitas_ready, lst = ap.preprocess_input_df(rf_for_aequitas)

# %%
# rf_for_aequitas_ready.info()

# %%
xtab, _ = g.get_crosstabs(rf_for_aequitas)
# Out:
# model_id, score_thresholds 1 {'rank_abs': [19603]}

# %%
absolute_metrics = g.list_absolute_metrics(xtab)

# %%
xtab[[col for col in xtab.columns if col not in absolute_metrics]]
# Out:
#     model_id score_threshold      k          attribute_name  \
# 0          1      binary 0/1  19603  median_income_quantile
# 1          1      binary 0/1  19603  median_income_quantile
# 2          1      binary 0/1  19603  median_income_quantile
# 3          1      binary 0/1  19603  median_income_quantile
# 4          1      binary 0/1  19603  median_income_quantile
# 5          1      binary 0/1  19603           race_majority
# 6          1      binary 0/1  19603           race_majority
# 7          1      binary 0/1  19603           race_majority
# 8          1      binary 0/1  19603           race_majority
# 9          1      binary 0/1  19603           race_majority
# 10         1      binary 0/1  19603           race_majority
# 11         1      binary 0/1  19603           race_majority
#
#           attribute_value     pp     pn     fp    fn     tn    tp  \
# 0         (0.0, 62500.25]  12874  57052  11086  1808  55244  1788
# 1   (125000.5, 187500.75]    361    672    340    16    656    21
# 2   (187500.75, 250001.0]     43     26     40     1     25     3
# 3    (62500.25, 125000.5]   4747  18612   4154   611  18001   593
# 4                     nan   1578   2043   1351    60   1983   227
# 5             asian alone    390    143    341     5    138    49
# 6             black alone   1814   4547   1587   141   4406   227
# 7            native alone    236    297    216     2    295    20
# 8             other alone    214    126    189     4    122    25
# 9           pacific alone      2      0      2     0      0     0
# 10            two or more     66     23     62     0     23     4
# 11            white alone  16881  73269  14574  2344  70925  2307
#
#     group_label_pos  group_label_neg  group_size  total_entities
# 0              3596            66330       69926           98008
# 1                37              996        1033           98008
# 2                 4               65          69           98008
# 3              1204            22155       23359           98008
# 4               287             3334        3621           98008
# 5                54              479         533           98008
# 6               368             5993        6361           98008
# 7                22              511         533           98008
# 8                29              311         340           98008
# 9                 0                2           2           98008
# 10                4               85          89           98008
# 11             4651            85499       90150           98008

# %%
xtab[['attribute_name', 'attribute_value'] + absolute_metrics].round(2)
# Out:
#             attribute_name        attribute_value   tpr   tnr   for   fdr  \
# 0   median_income_quantile        (0.0, 62500.25]  0.50  0.83  0.03  0.86
# 1   median_income_quantile  (125000.5, 187500.75]  0.57  0.66  0.02  0.94
# 2   median_income_quantile  (187500.75, 250001.0]  0.75  0.38  0.04  0.93
# 3   median_income_quantile   (62500.25, 125000.5]  0.49  0.81  0.03  0.88
# 4   median_income_quantile                    nan  0.79  0.59  0.03  0.86
# 5            race_majority            asian alone  0.91  0.29  0.03  0.87
# 6            race_majority            black alone  0.62  0.74  0.03  0.87
# 7            race_majority           native alone  0.91  0.58  0.01  0.92
# 8            race_majority            other alone  0.86  0.39  0.03  0.88
# 9            race_majority          pacific alone   NaN  0.00   NaN  1.00
# 10           race_majority            two or more  1.00  0.27  0.00  0.94
# 11           race_majority            white alone  0.50  0.83  0.03  0.86
#
#      fpr   fnr   npv  precision   ppr  pprev  prev
# 0   0.17  0.50  0.97       0.14  0.66   0.18  0.05
# 1   0.34  0.43  0.98       0.06  0.02   0.35  0.04
# 2   0.62  0.25  0.96       0.07  0.00   0.62  0.06
# 3   0.19  0.51  0.97       0.12  0.24   0.20  0.05
# 4   0.41  0.21  0.97       0.14  0.08   0.44  0.08
# 5   0.71  0.09  0.97       0.13  0.02   0.73  0.10
# 6   0.26  0.38  0.97       0.13  0.09   0.29  0.06
# 7   0.42  0.09  0.99       0.08  0.01   0.44  0.04
# 8   0.61  0.14  0.97       0.12  0.01   0.63  0.09
# 9   1.00   NaN   NaN       0.00  0.00   1.00  0.00
# 10  0.73  0.00  1.00       0.06  0.00   0.74  0.04
# 11  0.17  0.50  0.97       0.14  0.86   0.19  0.05

# %%
aqp = Plot()

# %%
p = aqp.plot_group_metric_all(xtab, ncols=3)

# %%
b = Bias()

# %%
bdf = b.get_disparity_predefined_groups(xtab, original_df=rf_for_aequitas, ref_groups_dict={'median_income_quantile':'(187500.75, 250001.0]', 'race_majority':'white alone'}, alpha=0.05, mask_significance=True)
bdf.style
# Out:
# get_disparity_predefined_group()
# <style  type="text/css" >
# </style><table id="T_42d76a58_8931_11e9_bc26_34363b744780" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >score_threshold</th>        <th class="col_heading level0 col2" >k</th>        <th class="col_heading level0 col3" >attribute_name</th>        <th class="col_heading level0 col4" >attribute_value</th>        <th class="col_heading level0 col5" >tpr</th>        <th class="col_heading level0 col6" >tnr</th>        <th class="col_heading level0 col7" >for</th>        <th class="col_heading level0 col8" >fdr</th>        <th class="col_heading level0 col9" >fpr</th>        <th class="col_heading level0 col10" >fnr</th>        <th class="col_heading level0 col11" >npv</th>        <th class="col_heading level0 col12" >precision</th>        <th class="col_heading level0 col13" >pp</th>        <th class="col_heading level0 col14" >pn</th>        <th class="col_heading level0 col15" >ppr</th>        <th class="col_heading level0 col16" >pprev</th>        <th class="col_heading level0 col17" >fp</th>        <th class="col_heading level0 col18" >fn</th>        <th class="col_heading level0 col19" >tn</th>        <th class="col_heading level0 col20" >tp</th>        <th class="col_heading level0 col21" >group_label_pos</th>        <th class="col_heading level0 col22" >group_label_neg</th>        <th class="col_heading level0 col23" >group_size</th>        <th class="col_heading level0 col24" >total_entities</th>        <th class="col_heading level0 col25" >prev</th>        <th class="col_heading level0 col26" >ppr_disparity</th>        <th class="col_heading level0 col27" >pprev_disparity</th>        <th class="col_heading level0 col28" >precision_disparity</th>        <th class="col_heading level0 col29" >fdr_disparity</th>        <th class="col_heading level0 col30" >for_disparity</th>        <th class="col_heading level0 col31" >fpr_disparity</th>        <th class="col_heading level0 col32" >fnr_disparity</th>        <th class="col_heading level0 col33" >tpr_disparity</th>        <th class="col_heading level0 col34" >tnr_disparity</th>        <th class="col_heading level0 col35" >npv_disparity</th>        <th class="col_heading level0 col36" >ppr_ref_group_value</th>        <th class="col_heading level0 col37" >pprev_ref_group_value</th>        <th class="col_heading level0 col38" >precision_ref_group_value</th>        <th class="col_heading level0 col39" >fdr_ref_group_value</th>        <th class="col_heading level0 col40" >for_ref_group_value</th>        <th class="col_heading level0 col41" >fpr_ref_group_value</th>        <th class="col_heading level0 col42" >fnr_ref_group_value</th>        <th class="col_heading level0 col43" >tpr_ref_group_value</th>        <th class="col_heading level0 col44" >tnr_ref_group_value</th>        <th class="col_heading level0 col45" >npv_ref_group_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42d76a58_8931_11e9_bc26_34363b744780level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col1" class="data row0 col1" >binary 0/1</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col2" class="data row0 col2" >19603</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col3" class="data row0 col3" >median_income_quantile</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col4" class="data row0 col4" >(0.0, 62500.25]</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col5" class="data row0 col5" >0.497219</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col6" class="data row0 col6" >0.832866</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col7" class="data row0 col7" >0.0316904</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col8" class="data row0 col8" >0.861115</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col9" class="data row0 col9" >0.167134</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col10" class="data row0 col10" >0.502781</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col11" class="data row0 col11" >0.96831</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col12" class="data row0 col12" >0.138885</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col13" class="data row0 col13" >12874</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col14" class="data row0 col14" >57052</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col15" class="data row0 col15" >0.656736</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col16" class="data row0 col16" >0.184109</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col17" class="data row0 col17" >11086</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col18" class="data row0 col18" >1808</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col19" class="data row0 col19" >55244</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col20" class="data row0 col20" >1788</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col21" class="data row0 col21" >3596</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col22" class="data row0 col22" >66330</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col23" class="data row0 col23" >69926</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col24" class="data row0 col24" >98008</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col25" class="data row0 col25" >0.0514258</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col26" class="data row0 col26" >299.395</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col27" class="data row0 col27" >0.295431</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col28" class="data row0 col28" >1.99068</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col29" class="data row0 col29" >0.925699</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col30" class="data row0 col30" >0.82395</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col31" class="data row0 col31" >0.271593</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col32" class="data row0 col32" >2.01112</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col33" class="data row0 col33" >0.662959</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col34" class="data row0 col34" >2.16545</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col35" class="data row0 col35" >1.00704</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col36" class="data row0 col36" >(187500.75, 250001.0]</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col37" class="data row0 col37" >(187500.75, 250001.0]</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col38" class="data row0 col38" >(187500.75, 250001.0]</td>
#                         <td id="T_42d76a58_8931_11e9_bc26_34363b744780row0_col39" class="data row0 col39" >(187500.75, 250001.0]</td>

# %%
calculated_disparities = b.list_disparities(bdf)
disparity_significance = b.list_significance(bdf)

# %%
bdf[['attribute_name', 'attribute_value'] +  calculated_disparities + disparity_significance]
# Out:
#             attribute_name        attribute_value  ppr_disparity  \
# 0   median_income_quantile        (0.0, 62500.25]     299.395349
# 1   median_income_quantile  (125000.5, 187500.75]       8.395349
# 2   median_income_quantile  (187500.75, 250001.0]       1.000000
# 3   median_income_quantile   (62500.25, 125000.5]     110.395349
# 4   median_income_quantile                    nan      36.697674
# 5            race_majority            asian alone       0.023103
# 6            race_majority            black alone       0.107458
# 7            race_majority           native alone       0.013980
# 8            race_majority            other alone       0.012677
# 9            race_majority          pacific alone       0.000118
# 10           race_majority            two or more       0.003910
# 11           race_majority            white alone       1.000000
#
#     pprev_disparity  precision_disparity  fdr_disparity  for_disparity  \
# 0          0.295431             1.990679       0.925699       0.823950
# 1          0.560774             0.833795       1.012465       0.619048
# 2          1.000000             1.000000       1.000000       1.000000
# 3          0.326096             1.790534       0.940710       0.853535
# 4          0.699293             2.061893       0.920358       0.763583
# 5          3.907554             0.919352       1.012766       1.092941
# 6          1.522928             0.915670       1.013349       0.969297
# 7          2.364571             0.620110       1.060135       0.210492
# 8          3.361262             0.854824       1.022981       0.992321
# 9          5.340323             0.000000       1.158296            NaN
# 10         3.960240             0.443472       1.088096       0.000000
# 11         1.000000             1.000000       1.000000       1.000000
#
#     fpr_disparity  fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity
# 0        0.271593       2.011123       0.662959       2.165452       1.007042
# 1        0.554719       1.729730       0.756757       1.712450       1.015238
# 2        1.000000       1.000000       1.000000       1.000000       1.000000
# 3        0.304683       2.029900       0.656700       2.112507       1.005859
# 4        0.658481       0.836237       1.054588       1.546431       1.009457
# 5        4.176391       0.183724       1.829368       0.347300       0.996928
# 6        1.553513       0.760256       1.243589       0.886262       1.001015
# 7        2.479791       0.180383       1.832762       0.695926       1.026092
# 8        3.565198       0.273685       1.737964       0.472891       1.000254
# 9        5.866543            NaN            NaN       0.000000            NaN
# 10       4.279126       0.000000       2.016038       0.326190       1.033049
# 11       1.000000       1.000000       1.000000       1.000000       1.000000

# %%
hbdf = b.get_disparity_predefined_groups(xtab, original_df=rf_for_aequitas, 
                                         ref_groups_dict={'median_income_quantile':'(187500.75, 250001.0]', 'race_majority':'white alone'},
                                         alpha=0.05,
                                         mask_significance=False)
# Out:
# get_disparity_predefined_group()

# %%
hbdf[['attribute_name', 'attribute_value'] +  calculated_disparities + disparity_significance]
# Out:
#             attribute_name        attribute_value  ppr_disparity  \
# 0   median_income_quantile        (0.0, 62500.25]     299.395349
# 1   median_income_quantile  (125000.5, 187500.75]       8.395349
# 2   median_income_quantile  (187500.75, 250001.0]       1.000000
# 3   median_income_quantile   (62500.25, 125000.5]     110.395349
# 4   median_income_quantile                    nan      36.697674
# 5            race_majority            asian alone       0.023103
# 6            race_majority            black alone       0.107458
# 7            race_majority           native alone       0.013980
# 8            race_majority            other alone       0.012677
# 9            race_majority          pacific alone       0.000118
# 10           race_majority            two or more       0.003910
# 11           race_majority            white alone       1.000000
#
#     pprev_disparity  precision_disparity  fdr_disparity  for_disparity  \
# 0          0.295431             1.990679       0.925699       0.823950
# 1          0.560774             0.833795       1.012465       0.619048
# 2          1.000000             1.000000       1.000000       1.000000
# 3          0.326096             1.790534       0.940710       0.853535
# 4          0.699293             2.061893       0.920358       0.763583
# 5          3.907554             0.919352       1.012766       1.092941
# 6          1.522928             0.915670       1.013349       0.969297
# 7          2.364571             0.620110       1.060135       0.210492
# 8          3.361262             0.854824       1.022981       0.992321
# 9          5.340323             0.000000       1.158296            NaN
# 10         3.960240             0.443472       1.088096       0.000000
# 11         1.000000             1.000000       1.000000       1.000000
#
#     fpr_disparity  fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity
# 0        0.271593       2.011123       0.662959       2.165452       1.007042
# 1        0.554719       1.729730       0.756757       1.712450       1.015238
# 2        1.000000       1.000000       1.000000       1.000000       1.000000
# 3        0.304683       2.029900       0.656700       2.112507       1.005859
# 4        0.658481       0.836237       1.054588       1.546431       1.009457
# 5        4.176391       0.183724       1.829368       0.347300       0.996928
# 6        1.553513       0.760256       1.243589       0.886262       1.001015
# 7        2.479791       0.180383       1.832762       0.695926       1.026092
# 8        3.565198       0.273685       1.737964       0.472891       1.000254
# 9        5.866543            NaN            NaN       0.000000            NaN
# 10       4.279126       0.000000       2.016038       0.326190       1.033049
# 11       1.000000       1.000000       1.000000       1.000000       1.000000

# %%
majority_bdf = b.get_disparity_major_group(xtab, original_df=rf_for_aequitas, mask_significance=True)
# Out:
# get_disparity_major_group()

# %%
majority_bdf[['attribute_name', 'attribute_value'] +  calculated_disparities + disparity_significance]
# Out:
#             attribute_name        attribute_value  ppr_disparity  \
# 0   median_income_quantile        (0.0, 62500.25]       1.000000
# 1   median_income_quantile  (125000.5, 187500.75]       0.028041
# 2   median_income_quantile  (187500.75, 250001.0]       0.003340
# 3   median_income_quantile   (62500.25, 125000.5]       0.368728
# 4   median_income_quantile                    nan       0.122573
# 5            race_majority            asian alone       0.023103
# 6            race_majority            black alone       0.107458
# 7            race_majority           native alone       0.013980
# 8            race_majority            other alone       0.012677
# 9            race_majority          pacific alone       0.000118
# 10           race_majority            two or more       0.003910
# 11           race_majority            white alone       1.000000
#
#     pprev_disparity  precision_disparity  fdr_disparity  for_disparity  \
# 0          1.000000             1.000000       1.000000       1.000000
# 1          1.898157             0.418850       1.093731       0.751317
# 2          3.384890             0.502341       1.080265       1.213666
# 3          1.103799             0.899459       1.016216       1.035907
# 4          2.367029             1.035774       0.994230       0.926735
# 5          3.907554             0.919352       1.012766       1.092941
# 6          1.522928             0.915670       1.013349       0.969297
# 7          2.364571             0.620110       1.060135       0.210492
# 8          3.361262             0.854824       1.022981       0.992321
# 9          5.340323             0.000000       1.158296            NaN
# 10         3.960240             0.443472       1.088096       0.000000
# 11         1.000000             1.000000       1.000000       1.000000
#
#     fpr_disparity  fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity
# 0        1.000000       1.000000       1.000000       1.000000       1.000000
# 1        2.042465       0.860081       1.141484       0.790805       1.008139
# 2        3.681983       0.497235       1.508389       0.461797       0.993007
# 3        1.121837       1.009337       0.990559       0.975551       0.998825
# 4        2.424515       0.415806       1.590729       0.714138       1.002398
# 5        4.176391       0.183724       1.829368       0.347300       0.996928
# 6        1.553513       0.760256       1.243589       0.886262       1.001015
# 7        2.479791       0.180383       1.832762       0.695926       1.026092
# 8        3.565198       0.273685       1.737964       0.472891       1.000254
# 9        5.866543            NaN            NaN       0.000000            NaN
# 10       4.279126       0.000000       2.016038       0.326190       1.033049
# 11       1.000000       1.000000       1.000000       1.000000       1.000000

# %%
min_metric_bdf = b.get_disparity_min_metric(df=xtab, original_df=rf_for_aequitas)
# Out:
# get_disparity_min_metric()

# %%
min_metric_bdf.style
# Out:
# <style  type="text/css" >
# </style><table id="T_69d80eaa_8931_11e9_bc26_34363b744780" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >score_threshold</th>        <th class="col_heading level0 col2" >k</th>        <th class="col_heading level0 col3" >attribute_name</th>        <th class="col_heading level0 col4" >attribute_value</th>        <th class="col_heading level0 col5" >tpr</th>        <th class="col_heading level0 col6" >tnr</th>        <th class="col_heading level0 col7" >for</th>        <th class="col_heading level0 col8" >fdr</th>        <th class="col_heading level0 col9" >fpr</th>        <th class="col_heading level0 col10" >fnr</th>        <th class="col_heading level0 col11" >npv</th>        <th class="col_heading level0 col12" >precision</th>        <th class="col_heading level0 col13" >pp</th>        <th class="col_heading level0 col14" >pn</th>        <th class="col_heading level0 col15" >ppr</th>        <th class="col_heading level0 col16" >pprev</th>        <th class="col_heading level0 col17" >fp</th>        <th class="col_heading level0 col18" >fn</th>        <th class="col_heading level0 col19" >tn</th>        <th class="col_heading level0 col20" >tp</th>        <th class="col_heading level0 col21" >group_label_pos</th>        <th class="col_heading level0 col22" >group_label_neg</th>        <th class="col_heading level0 col23" >group_size</th>        <th class="col_heading level0 col24" >total_entities</th>        <th class="col_heading level0 col25" >prev</th>        <th class="col_heading level0 col26" >ppr_disparity</th>        <th class="col_heading level0 col27" >ppr_ref_group_value</th>        <th class="col_heading level0 col28" >pprev_disparity</th>        <th class="col_heading level0 col29" >pprev_ref_group_value</th>        <th class="col_heading level0 col30" >precision_disparity</th>        <th class="col_heading level0 col31" >precision_ref_group_value</th>        <th class="col_heading level0 col32" >fdr_disparity</th>        <th class="col_heading level0 col33" >fdr_ref_group_value</th>        <th class="col_heading level0 col34" >for_disparity</th>        <th class="col_heading level0 col35" >for_ref_group_value</th>        <th class="col_heading level0 col36" >fpr_disparity</th>        <th class="col_heading level0 col37" >fpr_ref_group_value</th>        <th class="col_heading level0 col38" >fnr_disparity</th>        <th class="col_heading level0 col39" >fnr_ref_group_value</th>        <th class="col_heading level0 col40" >tpr_disparity</th>        <th class="col_heading level0 col41" >tpr_ref_group_value</th>        <th class="col_heading level0 col42" >tnr_disparity</th>        <th class="col_heading level0 col43" >tnr_ref_group_value</th>        <th class="col_heading level0 col44" >npv_disparity</th>        <th class="col_heading level0 col45" >npv_ref_group_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69d80eaa_8931_11e9_bc26_34363b744780level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col1" class="data row0 col1" >binary 0/1</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col2" class="data row0 col2" >19603</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col3" class="data row0 col3" >median_income_quantile</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col4" class="data row0 col4" >(0.0, 62500.25]</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col5" class="data row0 col5" >0.497219</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col6" class="data row0 col6" >0.832866</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col7" class="data row0 col7" >0.0316904</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col8" class="data row0 col8" >0.861115</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col9" class="data row0 col9" >0.167134</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col10" class="data row0 col10" >0.502781</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col11" class="data row0 col11" >0.96831</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col12" class="data row0 col12" >0.138885</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col13" class="data row0 col13" >12874</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col14" class="data row0 col14" >57052</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col15" class="data row0 col15" >0.656736</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col16" class="data row0 col16" >0.184109</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col17" class="data row0 col17" >11086</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col18" class="data row0 col18" >1808</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col19" class="data row0 col19" >55244</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col20" class="data row0 col20" >1788</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col21" class="data row0 col21" >3596</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col22" class="data row0 col22" >66330</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col23" class="data row0 col23" >69926</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col24" class="data row0 col24" >98008</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col25" class="data row0 col25" >0.0514258</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col26" class="data row0 col26" >299.395</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col27" class="data row0 col27" >(187500.75, 250001.0]</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col28" class="data row0 col28" >1</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col29" class="data row0 col29" >(0.0, 62500.25]</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col30" class="data row0 col30" >2.38749</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col31" class="data row0 col31" >(125000.5, 187500.75]</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col32" class="data row0 col32" >1.0058</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col33" class="data row0 col33" >nan</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col34" class="data row0 col34" >1.331</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col35" class="data row0 col35" >(125000.5, 187500.75]</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col36" class="data row0 col36" >1</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col37" class="data row0 col37" >(0.0, 62500.25]</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col38" class="data row0 col38" >2.40497</td>
#                         <td id="T_69d80eaa_8931_11e9_bc26_34363b744780row0_col39" class="data row0 col39" >nan</td>
#                         <td id="T_69

# %%
min_metric_bdf[['attribute_name', 'attribute_value'] +  calculated_disparities + disparity_significance]
# Out:
#             attribute_name        attribute_value  ppr_disparity  \
# 0   median_income_quantile        (0.0, 62500.25]     299.395349
# 1   median_income_quantile  (125000.5, 187500.75]       8.395349
# 2   median_income_quantile  (187500.75, 250001.0]       1.000000
# 3   median_income_quantile   (62500.25, 125000.5]     110.395349
# 4   median_income_quantile                    nan      36.697674
# 5            race_majority            asian alone     195.000000
# 6            race_majority            black alone     907.000000
# 7            race_majority           native alone     118.000000
# 8            race_majority            other alone     107.000000
# 9            race_majority          pacific alone       1.000000
# 10           race_majority            two or more      33.000000
# 11           race_majority            white alone    8440.500000
#
#     pprev_disparity  precision_disparity  fdr_disparity  for_disparity  \
# 0          1.000000             2.387492       1.005803       1.330996
# 1          1.898157             1.000000       1.100078       1.000000
# 2          3.384890             1.199336       1.086534       1.615385
# 3          1.103799             2.147452       1.022113       1.378788
# 4          2.367029             2.472901       1.000000       1.233480
# 5          3.907554            10.000000       1.012766      10.000000
# 6          1.522928            10.000000       1.013349      10.000000
# 7          2.364571            10.000000       1.060135      10.000000
# 8          3.361262            10.000000       1.022981      10.000000
# 9          5.340323                  NaN       1.158296            NaN
# 10         3.960240            10.000000       1.088096            NaN
# 11         1.000000            10.000000       1.000000      10.000000
#
#     fpr_disparity  fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity
# 0        1.000000       2.404968       1.009531       2.165452       1.007042
# 1        2.042465       2.068468       1.152363       1.712450       1.015238
# 2        3.681983       1.195833       1.522766       1.000000       1.000000
# 3        1.121837       2.427422       1.000000       2.112507       1.005859
# 4        2.424515       1.000000       1.605890       1.546431       1.009457
# 5        4.176391      10.000000       1.829368      10.000000       1.000000
# 6        1.553513      10.000000       1.243589      10.000000       1.004099
# 7        2.479791      10.000000       1.832762      10.000000       1.029254
# 8        3.565198      10.000000       1.737964      10.000000       1.003336
# 9        5.866543            NaN            NaN            NaN            NaN
# 10       4.279126            NaN       2.016038      10.000000       1.036232
# 11       1.000000      10.000000       1.000000      10.000000       1.003081

# %%
aqp.plot_disparity(majority_bdf, group_metric='precision_disparity', attribute_name='median_income_quantile', significance_alpha=0.05)

# %%
min_met = aqp.plot_disparity_all(min_metric_bdf, attributes=['median_income_quantile'], significance_alpha=0.05)

# %%
min_met = aqp.plot_disparity_all(min_metric_bdf, attributes=['families_under_poverty_line'], significance_alpha=0.05)

# %%
min_met = aqp.plot_disparity_all(min_metric_bdf, attributes=['black alone'], significance_alpha=0.05)

# %%
min_met = aqp.plot_disparity_all(min_metric_bdf, attributes=['native alone'], significance_alpha=0.05)

# %%
tm_capped = aqp.plot_disparity_all(hbdf, attributes=['race_majority'], metrics = 'all', significance_alpha=0.05)

# %%
by_income = aqp.plot_disparity_all(hbdf, attributes=['median_income_quantile'], metrics = 'all', significance_alpha=0.05)

# %%
dp = aqp.plot_disparity_all(majority_bdf, metrics=['for_disparity', 'fpr_disparity'], significance_alpha=0.05)

# %%
f = Fairness()
fdf = f.get_group_value_fairness(bdf)

# %%
parity_detrminations = f.list_parities(fdf)

# %%
fdf[['attribute_name', 'attribute_value'] + absolute_metrics + calculated_disparities + parity_detrminations].style
# Out:
# <style  type="text/css" >
# </style><table id="T_52d8ad1c_8932_11e9_bc26_34363b744780" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >attribute_name</th>        <th class="col_heading level0 col1" >attribute_value</th>        <th class="col_heading level0 col2" >tpr</th>        <th class="col_heading level0 col3" >tnr</th>        <th class="col_heading level0 col4" >for</th>        <th class="col_heading level0 col5" >fdr</th>        <th class="col_heading level0 col6" >fpr</th>        <th class="col_heading level0 col7" >fnr</th>        <th class="col_heading level0 col8" >npv</th>        <th class="col_heading level0 col9" >precision</th>        <th class="col_heading level0 col10" >ppr</th>        <th class="col_heading level0 col11" >pprev</th>        <th class="col_heading level0 col12" >prev</th>        <th class="col_heading level0 col13" >ppr_disparity</th>        <th class="col_heading level0 col14" >pprev_disparity</th>        <th class="col_heading level0 col15" >precision_disparity</th>        <th class="col_heading level0 col16" >fdr_disparity</th>        <th class="col_heading level0 col17" >for_disparity</th>        <th class="col_heading level0 col18" >fpr_disparity</th>        <th class="col_heading level0 col19" >fnr_disparity</th>        <th class="col_heading level0 col20" >tpr_disparity</th>        <th class="col_heading level0 col21" >tnr_disparity</th>        <th class="col_heading level0 col22" >npv_disparity</th>        <th class="col_heading level0 col23" >NPV Parity</th>        <th class="col_heading level0 col24" >TypeI Parity</th>        <th class="col_heading level0 col25" >Supervised Fairness</th>        <th class="col_heading level0 col26" >FPR Parity</th>        <th class="col_heading level0 col27" >TypeII Parity</th>        <th class="col_heading level0 col28" >FDR Parity</th>        <th class="col_heading level0 col29" >TPR Parity</th>        <th class="col_heading level0 col30" >Impact Parity</th>        <th class="col_heading level0 col31" >Equalized Odds</th>        <th class="col_heading level0 col32" >Unsupervised Fairness</th>        <th class="col_heading level0 col33" >FOR Parity</th>        <th class="col_heading level0 col34" >TNR Parity</th>        <th class="col_heading level0 col35" >FNR Parity</th>        <th class="col_heading level0 col36" >Statistical Parity</th>        <th class="col_heading level0 col37" >Precision Parity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_52d8ad1c_8932_11e9_bc26_34363b744780level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col0" class="data row0 col0" >median_income_quantile</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col1" class="data row0 col1" >(0.0, 62500.25]</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col2" class="data row0 col2" >0.497219</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col3" class="data row0 col3" >0.832866</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col4" class="data row0 col4" >0.0316904</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col5" class="data row0 col5" >0.861115</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col6" class="data row0 col6" >0.167134</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col7" class="data row0 col7" >0.502781</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col8" class="data row0 col8" >0.96831</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col9" class="data row0 col9" >0.138885</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col10" class="data row0 col10" >0.656736</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col11" class="data row0 col11" >0.184109</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col12" class="data row0 col12" >0.0514258</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col13" class="data row0 col13" >299.395</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col14" class="data row0 col14" >0.295431</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col15" class="data row0 col15" >1.99068</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col16" class="data row0 col16" >0.925699</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col17" class="data row0 col17" >0.82395</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col18" class="data row0 col18" >0.271593</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col19" class="data row0 col19" >2.01112</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col20" class="data row0 col20" >0.662959</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col21" class="data row0 col21" >2.16545</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col22" class="data row0 col22" >1.00704</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col23" class="data row0 col23" >True</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col24" class="data row0 col24" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col25" class="data row0 col25" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col26" class="data row0 col26" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col27" class="data row0 col27" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col28" class="data row0 col28" >True</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col29" class="data row0 col29" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col30" class="data row0 col30" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col31" class="data row0 col31" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col32" class="data row0 col32" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col33" class="data row0 col33" >True</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col34" class="data row0 col34" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col35" class="data row0 col35" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col36" class="data row0 col36" >False</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row0_col37" class="data row0 col37" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_52d8ad1c_8932_11e9_bc26_34363b744780level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row1_col0" class="data row1 col0" >median_income_quantile</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row1_col1" class="data row1 col1" >(125000.5, 187500.75]</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row1_col2" class="data row1 col2" >0.567568</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row1_col3" class="data row1 col3" >0.658635</td>
#                         <td id="T_52d8ad1c_8932_11e9_bc26_34363b744780row1_col4" class="data row1 col4" >0.0238095</td>
#                         <td id=

# %%
gaf = f.get_group_attribute_fairness(fdf)
gaf
# Out:
#    model_id score_threshold          attribute_name  Statistical Parity  \
# 0         1      binary 0/1  median_income_quantile               False
# 1         1      binary 0/1           race_majority               False
#
#    Impact Parity  FDR Parity  FPR Parity  FOR Parity  FNR Parity  TPR Parity  \
# 0          False        True       False       False       False       False
# 1          False        True       False       False       False       False
#
#    TNR Parity  NPV Parity  Precision Parity  TypeI Parity  TypeII Parity  \
# 0       False        True             False         False          False
# 1       False        True             False         False          False
#
#    Equalized Odds  Unsupervised Fairness  Supervised Fairness
# 0           False                  False                False
# 1           False                  False                False

# %%
gof = f.get_overall_fairness(fdf)
gof
# Out:
# {'Unsupervised Fairness': False,
#  'Supervised Fairness': False,
#  'Overall Fairness': False}

# %%
z = aqp.plot_fairness_group(fdf, group_metric='ppr')

# %%
fg = aqp.plot_fairness_group_all(fdf, ncols=5, metrics = "all")

# %%
n_tm = aqp.plot_fairness_disparity_all(fdf, attributes=['median_income_quantile', 'race_majority'], 
                                       significance_alpha=0.05)
